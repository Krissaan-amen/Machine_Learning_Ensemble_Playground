# %%
import numpy as np
import pandas as pd
# import clone
from sklearn.base import clone
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.datasets import load_breast_cancer

# import cross_validate
from sklearn.model_selection import cross_validate, StratifiedKFold

# %%
class BaggedTreeClassifier(object):
        def __init__(self, n_elements=100):
                self.n_elements = n_elements
                self.models = []

        def __del__(self):
                del self.n_elements
                del self.models

        def __make_bootsraps(self, data):
                dc = {}
                unip = 0
                b_size = data.shape[0]
                idx = [i for i in range(b_size)]
                for b in range (self.n_elements):
                        sidx = np.random.choice(idx, b_size, replace=True)
                        b_samp = data[sidx, :]
                        unip += len(set(sidx))
                        oidx = list(set(idx) - set(sidx))
                        o_samp = np.array([])
                        if oidx:
                                o_samp = data[oidx, :]
                        dc['boot_'+str(b)] = {'boot' : b_samp,'test' : o_samp}
                return dc


        def get_params(self, deep=True):
                return {'n_elements': self.n_elements}

        def fit(self, X_train, y_train, print_metrics=False):
                training_data = np.concatenate((X_train, y_train.reshape(-1, 1)), axis=1)
                dcBoot = self.__make_bootsraps(training_data)

                accs = np.array([])
                pres = np.array([])
                recs = np.array([])

                cls = DecisionTreeClassifier(class_weight='balanced')
                for b in dcBoot:
                        model = clone(cls)
                        model.fit(dcBoot[b]['boot'][:, :-1], dcBoot[b]['boot'][:, -1].reshape(-1, 1))

                        self.models.append(model)

                        if dcBoot[b]['test'].size:
                                yp = model.predict(dcBoot[b]['test'][:, :-1])
                                acc = accuracy_score(dcBoot[b]['test'][:, -1], yp)
                                pre = precision_score(dcBoot[b]['test'][:, -1], yp)
                                rec = recall_score(dcBoot[b]['test'][:, -1], yp)

                                accs = np.concatenate((accs, acc.flatten()))
                                pres = np.concatenate((pres, pre.flatten()))
                                recs = np.concatenate((recs, rec.flatten()))

                        if print_metrics:
                                print('Standard error in accuracy: ', np.std(accs))
                                print('Standard error in precision: ', np.std(pres))
                                print('Standard error in recall: ', np.std(recs))

        def predict(self, X):
                if not self.models:
                        print('No models found. Please train the model first.')
                        return None
                predictions = []
                for m in self.models:
                        yp = m.predict(X)
                        predictions.append(yp.reshape(-1, 1))
                ypred = np.round(np.mean(np.concatenate(predictions, axis=1), axis=1))
                return ypred

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
ens = BaggedTreeClassifier()
ens.fit(X, y, print_metrics=True)
# Out:
# Standard error in accuracy:  0.0
# Standard error in precision:  0.0
# Standard error in recall:  0.0
# Standard error in accuracy:  0.02271824237466402
# Standard error in precision:  0.004601648351648391
# Standard error in recall:  0.04162531017369725
# Standard error in accuracy:  0.02073421410406947
# Standard error in precision:  0.0049057604636934295
# Standard error in recall:  0.0373723509823977
# Standard error in accuracy:  0.02069528593160894
# Standard error in precision:  0.00648003198994401
# Standard error in recall:  0.03464406409881267
# Standard error in accuracy:  0.021437593538067738
# Standard error in precision:  0.006486587056846458
# Standard error in recall:  0.03791430916487297
# Standard error in accuracy:  0.020417738555164083
# Standard error in precision:  0.005948606899802399
# Standard error in recall:  0.03658260123817905
# Standard error in accuracy:  0.01908084527158395
# Standard error in precision:  0.005634111960175172
# Standard error in recall:  0.03476612836213352
# Standard error in accuracy:  0.01987800359800183
# Standard error in precision:  0.012303172175630749
# Standard error in recall:  0.032548481969928
# Standard error in accuracy:  0.018959566679152322
# Standard error in precision:  0.012151784483578771
# Standard error in recall:  0.030788719516448165
# Standard error in accuracy:  0.018335622454917953
# Standard error in precision:  0.011553464540394973
# Standard error in recall:  0.030038067386897262
# Standard error in accuracy:  0.01751328428152624
# Standard error in precision:  0.011029929198312319
# Standard error in recall:  0.028655928811084884
# Standard error in accuracy:  0.01732049037840045
# Standard error in precision:  0.013114483140620796
# Standard error in recall:  0.027468125538874257
# Standard error in accuracy:  0.0176151465781895
# Standard error in precision:  0.014632421481682225
# Standard error in recall:  0.02642197120237455
# Standard error in accuracy:  0.01698423544038138
# Standard error in precision:  0.014116756707468859
# Standard error in recall:  0.025690024057258082
# Standard error in accuracy:  0.017246010828563064
# Standard error in precision:  0.01392620717746482
# Standard error in recall:  0.025548709823556618
# Standard error in accuracy:  0.01684358575100629
# Standard error in precision:  0.0140518649552846
# Standard error in recall:  0.02480514489602606
# Standard error in accuracy:  0.01640642546078499
# Standard error in precision:  0.0137905331053635
# Standard error in recall:  0.02408470521021953
# Standard error in accuracy:  0.01900176826295803
# Standard error in precision:  0.013428031028087355
# Standard error in recall:  0.028252580586956927
# Standard error in accuracy:  0.01852388165012228
# Standard error in precision:  0.013241011045785067
# Standard error in recall:  0.02752720631740544
# Standard error in accuracy:  0.018092164536813178
# Standard error in precision:  0.013916594095038422
# Standard error in recall:  0.027893875521919076
# Standard error in accuracy:  0.01802594084593368
# Standard error in precision:  0.013753044610325874
# Standard error in recall:  0.027598164315412836
# Standard error in accuracy:  0.017629687551896346
# Standard error in precision:  0.014711096245186383
# Standard error in recall:  0.027796359309494374
# Standard error in accuracy:  0.01884950609865916
# Standard error in precision:  0.014615326922638417
# Standard error in recall:  0.03163086516568592
# Standard error in accuracy:  0.018534715662819636
# Standard error in precision:  0.014333220395486746
# Standard error in recall:  0.030987818166196574
# Standard error in accuracy:  0.019597249171420403
# Standard error in precision:  0.015010039026847565
# Standard error in recall:  0.031101049792958795
# Standard error in accuracy:  0.019584878202726936
# Standard error in precision:  0.01480579197673885
# Standard error in recall:  0.030722908049736018
# Standard error in accuracy:  0.01957579793995668
# Standard error in precision:  0.017841100084714172
# Standard error in recall:  0.030479747715607325
# Standard error in accuracy:  0.019368694108059185
# Standard error in precision:  0.017550424632038562
# Standard error in recall:  0.030193222615675825
# Standard error in accuracy:  0.019289472991993684
# Standard error in precision:  0.017283132599839598
# Standard error in recall:  0.030220373256155893
# Standard error in accuracy:  0.019488393170856416
# Standard error in precision:  0.018099063729262777
# Standard error in recall:  0.029740182200144252
# Standard error in accuracy:  0.020334776365044587
# Standard error in precision:  0.017927812068668766
# Standard error in recall:  0.030434605812794446
# Standard error in accuracy:  0.020232165417808978
# Standard error in precision:  0.0177135073650297
# Standard error in recall:  0.03018095527374386
# Standard error in accuracy:  0.020131105323084528
# Standard error in precision:  0.01745424646861652
# Standard error in recall:  0.030093114904720775
# Standard error in accuracy:  0.019984170936560564
# Standard error in precision:  0.017203937630308336
# Standard error in recall:  0.029851114869077006
# Standard error in accuracy:  0.019848359287411715
# Standard error in precision:  0.017293076415211293
# Standard error in recall:  0.029434378191497492
# Standard error in accuracy:  0.019773848320612
# Standard error in precision:  0.01711694606245455
# Standard error in recall:  0.029623345441895346
# Standard error in accuracy:  0.01959818454847704
# Standard error in precision:  0.017078396950562246
# Standard error in recall:  0.029983575530904447
# Standard error in accuracy:  0.01951073588145463
# Standard error in precision:  0.016854064522356417
# Standard error in recall:  0.029684699053373956
# Standard error in accuracy:  0.019459869526988915
# Standard error in precision:  0.016708986109513223
# Standard error in recall:  0.02997686738674548
# Standard error in accuracy:  0.019366124201376737
# Standard error in precision:  0.017100240202574665
# Standard error in recall:  0.030737066299216787
# Standard error in accuracy:  0.019187856711528624
# Standard error in precision:  0.017407182665749046
# Standard error in recall:  0.03037952894597424
# Standard error in accuracy:  0.018978177616156867
# Standard error in precision:  0.017542061865575602
# Standard error in recall:  0.030023458106112625
# Standard error in accuracy:  0.019442505146611725
# Standard error in precision:  0.01860206577986351
# Standard error in recall:  0.02992731405768843
# Standard error in accuracy:  0.019275387994712102
# Standard error in precision:  0.01840439561724841
# Standard error in recall:  0.029615367464151512
# Standard error in accuracy:  0.01906144574426699
# Standard error in precision:  0.018284199519275304
# Standard error in recall:  0.029299490477568767
# Standard error in accuracy:  0.019048639481473978
# Standard error in precision:  0.018109224791929977
# Standard error in recall:  0.029197627295112515
# Standard error in accuracy:  0.018917739335310498
# Standard error in precision:  0.01791979606694286
# Standard error in recall:  0.02906203328760307
# Standard error in accuracy:  0.018951591552320124
# Standard error in precision:  0.01778814523519763
# Standard error in recall:  0.02888591227203784
# Standard error in accuracy:  0.01910269609822507
# Standard error in precision:  0.019938999234685235
# Standard error in recall:  0.02881510465911094
# Standard error in accuracy:  0.018932631496071946
# Standard error in precision:  0.020368204635682015
# Standard error in recall:  0.028803937896026623
# Standard error in accuracy:  0.019028464923356882
# Standard error in precision:  0.02036246074116277
# Standard error in recall:  0.0286332806387163
# Standard error in accuracy:  0.019517581237055444
# Standard error in precision:  0.020166128959547946
# Standard error in recall:  0.029833032182227433
# Standard error in accuracy:  0.019437124514053834
# Standard error in precision:  0.02048216447481367
# Standard error in recall:  0.029554456212534583
# Standard error in accuracy:  0.019673575358398667
# Standard error in precision:  0.02109342014933781
# Standard error in recall:  0.029291354796198533
# Standard error in accuracy:  0.01953352937301644
# Standard error in precision:  0.02090095085857813
# Standard error in recall:  0.029086451335754313
# Standard error in accuracy:  0.019670644835285404
# Standard error in precision:  0.020804157982779712
# Standard error in recall:  0.029077600115112717
# Standard error in accuracy:  0.02047129230536694
# Standard error in precision:  0.021038131632345587
# Standard error in recall:  0.029431529137347878
# Standard error in accuracy:  0.020614502892759862
# Standard error in precision:  0.021095818261082297
# Standard error in recall:  0.02927169911950172
# Standard error in accuracy:  0.020446268420045235
# Standard error in precision:  0.02114138591938054
# Standard error in recall:  0.029178845876107876
# Standard error in accuracy:  0.020354969179330606
# Standard error in precision:  0.020970279120898817
# Standard error in recall:  0.029087877981902266
# Standard error in accuracy:  0.02022509255755902
# Standard error in precision:  0.020810432417669972
# Standard error in recall:  0.028850500860289414
# Standard error in accuracy:  0.020152124772868145
# Standard error in precision:  0.02066407308351432
# Standard error in recall:  0.028642872766796987
# Standard error in accuracy:  0.020743703003241982
# Standard error in precision:  0.021381471431830685
# Standard error in recall:  0.02877584930928214
# Standard error in accuracy:  0.02073225815433974
# Standard error in precision:  0.021249275294289657
# Standard error in recall:  0.02908242828375816
# Standard error in accuracy:  0.020572395888808638
# Standard error in precision:  0.021110264731045537
# Standard error in recall:  0.028927746789949024
# Standard error in accuracy:  0.0204267459170223
# Standard error in precision:  0.020959506309163232
# Standard error in recall:  0.028711887565297717
# Standard error in accuracy:  0.020273851824458296
# Standard error in precision:  0.020992163098324766
# Standard error in recall:  0.028577678098117478
# Standard error in accuracy:  0.020132884886704127
# Standard error in precision:  0.020854607577374944
# Standard error in recall:  0.02850599129777641
# Standard error in accuracy:  0.020465208437334657
# Standard error in precision:  0.02071034401296547
# Standard error in recall:  0.028740881893108847
# Standard error in accuracy:  0.02034221268696451
# Standard error in precision:  0.02067296408673425
# Standard error in recall:  0.0287281590598016
# Standard error in accuracy:  0.020275819995991033
# Standard error in precision:  0.020564082947262325
# Standard error in recall:  0.028566666349912166
# Standard error in accuracy:  0.020138255863782383
# Standard error in precision:  0.020448340186116222
# Standard error in recall:  0.028381241250366198
# Standard error in accuracy:  0.020019755848186604
# Standard error in precision:  0.020538747917505405
# Standard error in recall:  0.028221855349207604
# Standard error in accuracy:  0.02029844083070274
# Standard error in precision:  0.020471104394330638
# Standard error in recall:  0.028507937817540435
# Standard error in accuracy:  0.02018502762357049
# Standard error in precision:  0.02036370457760426
# Standard error in recall:  0.028322515895559217
# Standard error in accuracy:  0.020051933986632124
# Standard error in precision:  0.02037966769014125
# Standard error in recall:  0.028254165686241096
# Standard error in accuracy:  0.020092297708986052
# Standard error in precision:  0.020644401923270474
# Standard error in recall:  0.02808339710371675
# Standard error in accuracy:  0.020009837217316605
# Standard error in precision:  0.02102523195430223
# Standard error in recall:  0.027965874009749547
# Standard error in accuracy:  0.02027454768462094
# Standard error in precision:  0.020921519380252062
# Standard error in recall:  0.028118771222828312
# Standard error in accuracy:  0.020628423667093346
# Standard error in precision:  0.022148161420155004
# Standard error in recall:  0.0279696153395196
# Standard error in accuracy:  0.02059727770142337
# Standard error in precision:  0.022011023586037366
# Standard error in recall:  0.028096395094824467
# Standard error in accuracy:  0.02054957426042393
# Standard error in precision:  0.02234195000762211
# Standard error in recall:  0.02793307450182992
# Standard error in accuracy:  0.020729937765597884
# Standard error in precision:  0.02329477082604927
# Standard error in recall:  0.027780222976496433
# Standard error in accuracy:  0.020617814515085927
# Standard error in precision:  0.023236386650505172
# Standard error in recall:  0.027669747119112364
# Standard error in accuracy:  0.02062215446805268
# Standard error in precision:  0.02339849605495291
# Standard error in recall:  0.027513199537174026
# Standard error in accuracy:  0.020502490244528843
# Standard error in precision:  0.023299531783531304
# Standard error in recall:  0.027368929795571175
# Standard error in accuracy:  0.020454952749861786
# Standard error in precision:  0.023244380839362398
# Standard error in recall:  0.027212943910014893
# Standard error in accuracy:  0.020583518923752174
# Standard error in precision:  0.023863229933394948
# Standard error in recall:  0.02709401707243853
# Standard error in accuracy:  0.020976997555855116
# Standard error in precision:  0.024027826730029907
# Standard error in recall:  0.027198101220052298
# Standard error in accuracy:  0.020969440246124585
# Standard error in precision:  0.023923515936884413
# Standard error in recall:  0.02716878050542575
# Standard error in accuracy:  0.020994849936260666
# Standard error in precision:  0.024055387798786836
# Standard error in recall:  0.02702152796668118
# Standard error in accuracy:  0.02088318435254553
# Standard error in precision:  0.02392557643940718
# Standard error in recall:  0.02687508096755652
# Standard error in accuracy:  0.020771291404170614
# Standard error in precision:  0.023811564012746932
# Standard error in recall:  0.026730989424039182
# Standard error in accuracy:  0.02067589542582819
# Standard error in precision:  0.023694266999919954
# Standard error in recall:  0.026598006729171307
# Standard error in accuracy:  0.02058317631093722
# Standard error in precision:  0.02360551649550459
# Standard error in recall:  0.026462610021064734
# Standard error in accuracy:  0.020477183526216754
# Standard error in precision:  0.023522444102128046
# Standard error in recall:  0.026338887700942466
# Standard error in accuracy:  0.020383499194937513
# Standard error in precision:  0.023428374246514415
# Standard error in recall:  0.02626322537011396
# Standard error in accuracy:  0.020365614873375095
# Standard error in precision:  0.023310353658758613
# Standard error in recall:  0.026245988592092664
# Standard error in accuracy:  0.020304407233005316
# Standard error in precision:  0.02319856709790484
# Standard error in recall:  0.026115758499618065
# Standard error in accuracy:  0.02039610785956673
# Standard error in precision:  0.023134030597420835
# Standard error in recall:  0.02622607033564389

# %%
## use k fold cross validation to measure performance ##
scoring_metrics = ['accuracy', 'precision','recall']
dcScores = cross_validate(ens,X,y,cv=StratifiedKFold(10) ,scoring=scoring_metrics)
print('Mean Accuracy: %.2f' % np.mean (dcScores['test_accuracy']))
print('Mean Precision: %.2f' % np.mean(dcScores['test_precision']))
print('Mean Recall: %.2f' % np.mean(dcScores['test_recall']))
# Out:
# Mean Accuracy: 0.96
# Mean Precision: 0.96
# Mean Recall: 0.98

# %%
## import the scikit-learn model ##
from sklearn.ensemble import BaggingClassifier

# %%
ens = BaggingClassifier (base_estimator=DecisionTreeClassifier(class_weight='balanced' ),n_estimators=100)

# %%
## use k fold cross validation to measure performance ##
scoring_metrics = ['accuracy', 'precision', 'recall']
dcScores = cross_validate(ens,X,y,cv=StratifiedKFold(10),scoring=scoring_metrics)
print('Mean Accuracy: %.2f' % np.mean(dcScores['test_accuracy']))
print('Mean Precision: %.2f' % np.mean(dcScores['test_precision']))
print ('Mean Recall: %.2f' % np.mean(dcScores['test_recall']))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Mean Accuracy: 0.96
# Mean Precision: 0.97
# Mean Recall: 0.97
