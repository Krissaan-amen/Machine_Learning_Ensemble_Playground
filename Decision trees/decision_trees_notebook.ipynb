# %%
import pandas as pd
import pandas
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# %%
df  = pd.read_csv("data/comedian.csv")
print(df)
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES
# 13   45          10     2         USA   NO
# 14   85          12     5           N   NO
# 15   43          14     7         USA   NO
# 16   36           3     4         USA   NO
# 17   65          15     5         USA  YES
# 18   59           8     3           N   NO
# 19   98           9     6         USA   NO
# 20   78          51     4         USA   NO
# 21   20          26     8          UK  YES

# %%
d = {'UK' : 0, 'USA' : 1, 'N' : 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES' : 1, 'NO' : 0}
df['Go'] = df['Go'].map(d)

print(df)
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            0   0
# 1    42          12     4            1   0
# 2    23           4     6            2   0
# 3    52           4     4            1   0
# 4    43          21     8            1   1
# 5    44          14     5            0   0
# 6    66           3     7            2   1
# 7    35          14     9            0   1
# 8    52          13     7            2   1
# 9    35           5     9            2   1
# 10   24           3     5            1   0
# 11   18           3     7            0   1
# 12   45           9     9            0   1
# 13   45          10     2            1   0
# 14   85          12     5            2   0
# 15   43          14     7            1   0
# 16   36           3     4            1   0
# 17   65          15     5            1   1
# 18   59           8     3            2   0
# 19   98           9     6            1   0
# 20   78          51     4            1   0
# 21   20          26     8            0   1

# %%
#X is the feature columns, y is the target column
features = ['Age', 'Experience', 'Rank', 'Nationality']

X=df[features]
y = df ['Go']
print (X)
print (y)
# Out:
#     Age  Experience  Rank  Nationality
# 0    36          10     9            0
# 1    42          12     4            1
# 2    23           4     6            2
# 3    52           4     4            1
# 4    43          21     8            1
# 5    44          14     5            0
# 6    66           3     7            2
# 7    35          14     9            0
# 8    52          13     7            2
# 9    35           5     9            2
# 10   24           3     5            1
# 11   18           3     7            0
# 12   45           9     9            0
# 13   45          10     2            1
# 14   85          12     5            2
# 15   43          14     7            1
# 16   36           3     4            1
# 17   65          15     5            1
# 18   59           8     3            2
# 19   98           9     6            1
# 20   78          51     4            1
# 21   20          26     8            0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# 13    0
# 14    0
# 15    0
# 16    0
# 17    1
# 18    0
# 19    0
# 20    0
# 21    1
# Name: Go, dtype: int64

# %%
# Create a DecisionTreeClassifier object
dtree = DecisionTreeClassifier()

# Fit the DecisionTreeClassifier object to the training data
dtree = dtree.fit(X, y)

# Plot the decision tree
tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4, 0.9166666666666666, 'Rank <= 6.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2, 0.75, 'Experience <= 14.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.30000000000000004, 0.8333333333333333, 'True  '),
#  Text(0.1, 0.5833333333333334, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3, 0.5833333333333334, 'Experience <= 33.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.75, 'Experience <= 9.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.5, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7, 0.5833333333333334, 'Experience <= 11.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.4166666666666667, 'Rank <= 7.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7, 0.25, 'Nationality <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
# Create a DecisionTreeClassifier object
dtree = DecisionTreeClassifier(criterion = 'entropy')

# Fit the DecisionTreeClassifier object to the training data
dtree = dtree.fit(X, y)

# Plot the decision tree
tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4, 0.9166666666666666, 'Rank <= 6.5\nentropy = 0.976\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2, 0.75, 'Experience <= 14.5\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.30000000000000004, 0.8333333333333333, 'True  '),
#  Text(0.1, 0.5833333333333334, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3, 0.5833333333333334, 'Age <= 71.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.75, 'Experience <= 9.5\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.5, 0.5833333333333334, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7, 0.5833333333333334, 'Experience <= 11.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.4166666666666667, 'Rank <= 7.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7, 0.25, 'Nationality <= 1.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
# Create a DecisionTreeClassifier object
dtree = DecisionTreeClassifier(criterion = 'log_loss')

# Fit the DecisionTreeClassifier object to the training data
dtree = dtree.fit(X, y)

# Plot the decision tree
tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4, 0.9166666666666666, 'Rank <= 6.5\nlog_loss = 0.976\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2, 0.75, 'Experience <= 14.5\nlog_loss = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.30000000000000004, 0.8333333333333333, 'True  '),
#  Text(0.1, 0.5833333333333334, 'log_loss = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3, 0.5833333333333334, 'Experience <= 33.0\nlog_loss = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.4166666666666667, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.4166666666666667, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.75, 'Experience <= 9.5\nlog_loss = 0.722\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.5, 0.5833333333333334, 'log_loss = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7, 0.5833333333333334, 'Experience <= 11.5\nlog_loss = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6, 0.4166666666666667, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.4166666666666667, 'Rank <= 7.5\nlog_loss = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7, 0.25, 'Experience <= 13.5\nlog_loss = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6, 0.08333333333333333, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.08333333333333333, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9, 0.25, 'log_loss = 0.0\nsamples = 3\nvalue = [0, 3]')]
